# %%
import numpy as np
import pandas as pd

# %%
matches=pd.read_csv(r"C:\Users\GOPI\Downloads\matches.csv-20231125T054452Z-001.zip")

# %%
delivaries=pd.read_csv(r"C:\Users\GOPI\Downloads\deliveries.csv-20231125T054525Z-001.zip")

# %%
delivaries
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
matches
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
df=pd.DataFrame(left=match_id, right=id)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df=pd.DataFrame(left=match_id, right=id)
#
# NameError: name 'match_id' is not defined

# %%
delivaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %%
#  City which hosted most number of seasons according to the da
matches["season"].value_counts()
# Out:
# 2013    76
# 2012    74
# 2011    73
# 2010    60
# 2014    60
# 2016    60
# 2018    60
# 2019    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: season, dtype: int64

# %%
# Which year has the most number of matches played?
matches["city"].value_counts()
# Out:
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Ahmedabad          12
# Rajkot             10
# Mohali             10
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Cuttack             7
# Ranchi              7
# Port Elizabeth      7
# Cape Town           7
# Abu Dhabi           7
# Sharjah             6
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: city, dtype: int64

# %%
# Maximum wins by Mumbai Indians in 2011 are
len(matches.loc[(matches["winner"]=="Mumbai Indians") & (matches["season"]==2011)])
# Out:
# 10

# %%
# For 'toss_decision' feature what kind of plot is suitable?
matches["toss_decision"].unique()
# Out:
# array(['field', 'bat'], dtype=object)

# %%
# What is the percentage of getting bat and field in feature 'toss_descision'?
matches["toss_decision"].value_counts()
# Out:
# field    463
# bat      293
# Name: toss_decision, dtype: int64

# %%
field=np.percentile(m,range(1,100))
bat=np.percentile(m,range(1,100))

# %%
463/100
# Out:
# 4.63

# %%
#  In which years where taking batting second have won more number of matches?
matches.loc[(matches["toss_decision"]=="field") & matches["toss_winner"].value_counts(),["season"]]
# Out:
# Empty DataFrame
# Columns: [season]
# Index: []

# %%
#Most number of wickets taken by a bowler is
delivaries.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
g=delivaries.groupby("bowler")
# Out:
# 405

# %%
# In 2019 which batsman scored highest number of runs by hitting 6's and 4's?
delivaries.loc[(delivaries["season"]==2019)(delivaries["bowler"]=="Harbhajan Singh") & ((delivaries["batsman_runs"]==4) | (delivaries["batsman_runs"]==4))]
# Out:
#         match_id  inning           batting_team         bowling_team  over  \
# 1503           7       1  Kolkata Knight Riders       Mumbai Indians    13
# 1515           7       1  Kolkata Knight Riders       Mumbai Indians    15
# 1519           7       1  Kolkata Knight Riders       Mumbai Indians    15
# 2128          10       1    Sunrisers Hyderabad       Mumbai Indians     3
# 2129          10       1    Sunrisers Hyderabad       Mumbai Indians     3
# ...          ...     ...                    ...                  ...   ...
# 178637     11414       1         Delhi Capitals  Chennai Super Kings     8
# 178638     11414       1         Delhi Capitals  Chennai Super Kings     8
# 178854     11415       1         Mumbai Indians  Chennai Super Kings     4
# 178896     11415       1         Mumbai Indians  Chennai Super Kings    11
# 178899     11415       1         Mumbai Indians  Chennai Super Kings    11
#
# ...

# %%
# Bowlers with maximum number of extras:
delivaries.groupby("bowler").max("extra_runs")
# Out:
#                 match_id  inning  over  ball  is_super_over  wide_runs  \
# bowler
# A Ashish Reddy       584       2    20     7              0          3
# A Chandila           436       2    17     6              0          0
# A Choudhary           45       2    19     8              0          1
# A Dananjaya         7902       2    15     7              0          1
# A Flintoff           125       2    20     6              0          0
# ...                  ...     ...   ...   ...            ...        ...
# YA Abdulla           181       2    20     8              0          1
# YK Pathan          11310       2    20     9              0          5
# YS Chahal          11345       2    20     9              0          5
# Yuvraj Singh        7911       2    19     7              0          1
# Z Khan               632       2    20     9              0          5
#
#                 bye_runs  legbye_runs  noball_runs  penalty_runs  \
# bowler
# ...

# %%
#What are the total runs scored by V Kohli when the bowler was JJ Burmah?
delivaries.loc[(delivaries["batsman"]=="V Kohli") & (delivaries["bowler"]=="JJ Bumrah"),["total_runs"]].sum()
# Out:
# total_runs    114
# dtype: int64

# %%
#Across all seasons which player was dismissed the maximum number of times via caught and bowled
delivaries
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
delivaries["player_dismissed"].value_counts()
# Out:
# SK Raina      162
# RG Sharma     155
# RV Uthappa    153
# V Kohli       143
# S Dhawan      137
#              ...
# S Randiv        1
# R Ninan         1
# B Sumanth       1
# C Madan         1
# S Singh         1
# Name: player_dismissed, Length: 487, dtype: int64

# %%
#which player has the highest hard-hitting ability
