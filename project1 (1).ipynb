# %%
import numpy as np
from bs4 import BeautifulSoup 
import re
from urllib.request import urlopen
import pandas as pd

# %%
import requests

# %%
url=("https://www.flipkart.com/search?q=tv&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off%22&page=2")
#webdata=httpObject.read()
#print(webdata)

# %%
page = requests.get(url)

# %%
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content,"html.parser")

# %%
container=soup.find_all("div",class_="_1AtVbE col-12-12")
for i in container:
    text=i.text

# %%
container
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/home-entertainment/pr?sid=ckf&amp;q=tv&amp;otracker=categorytree" title="Home Entertainment">Home Entertainment</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/televisions/pr?sid=ckf,czl&amp;q=tv&amp
# ...

# %%
Title=[]
for i in range(1,41):
    url=(f"https://www.flipkart.com/search?q=tv&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={i}")
    container=soup.find_all("div",class_="_4rR01T")
    for i in container:
        text=i.text
        if text:
            Title.append(text)
        else:
            Title.append(np.nan)

# %%
Title
# Out:
# ['BeethoSOL 80 cm (32 inch) HD Ready LED Smart Android Based TV',
#  'Hisense E7K 139 cm (55 inch) QLED Ultra HD (4K) Smart VIDAA TV With Dolby Vision and Atmos',
#  'Mi A series 80 cm (32 inch) HD Ready LED Smart Google TV 2023 Edition with HD |Dolby Audio | DTS:HD | ...',
#  'MarQ by Flipkart 80 cm (32 inch) HD Ready LED TV',
#  'Hisense E7K 108 cm (43 inch) QLED Ultra HD (4K) Smart VIDAA TV With Dolby Vision and Atmos',
#  'Blaupunkt CyberSound G2 139 cm (55 inch) Ultra HD (4K) LED Smart Google TV 2023 Edition with Dolby Vis...',
#  'BeethoSOL 80 cm (32 inch) HD Ready LED TV',
#  'BeethoSOL 60 cm (24 inch) HD Ready LED TV',
#  'Acer Advanced I Series 127 cm (50 inch) Ultra HD (4K) LED Smart Google TV 2023 Edition with Dolby Visi...',
#  'TCL 43P635 108 cm (43 inch) Ultra HD (4K) LED Smart Google TV 2022 Edition with "Dolby Audio & HDR10"',
#  'Acer Advanced I Series 139 cm (55 inch) Ultra HD (4K) LED Smart Google TV 2023 Edition with Dolby Visi...',
# ...

# %%
len(Title)
# Out:
# 960

# %%
SellingPrice=[]
for i in range(1,41):
    url=("https://www.flipkart.com/search?q=tv&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off%22&page={i}")
    container=soup.find_all("div",class_="_30jeq3 _1_WHN1")
    for i in container:
        text=i.text
        if text:
            SellingPrice.append(text)
        else:
            SellingPrice.append(np.nan)

# %% [markdown]
# Wishlist=[]
# for i in range(1,11):
#     url="https://www.flipkart.com/search?q=tv&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"
#     container=soup.find_all("path",class_="eX72wL")
#     for i in container:
#         text=i.text
#         if text:
#             Wishlist.append(text)
#         else:
#             Wishlist.append(np.nan)

# %%
Warranty=[]
for i in range(1,41):
    url=("https://www.flipkart.com/search?q=tv&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off%22&page={i}")
    container=soup.find_all("ul",class_="_1xgFaf")
    for i in container:
        text=i.text
        if text:
            Warranty.append(text)
        else:
            Warranty.append(np.nan)

# %%
Rating=[]
for i in range(1,41):
    url=("https://www.flipkart.com/search?q=tv&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off%22&page={i}")
    container=soup.find_all("div",class_="col col-7-12")
    for i in container:
        text=i.find("div",class_="_3LWZlK")
        if text:
            Rating.append(text)
        else:
            Rating.append(np.nan)

# %%
pixcel=[]
for i in range(1,41):
    url=("https://www.flipkart.com/search?q=tv&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off%22&page={i}")
    container=soup.find_all("div",class_="col col-7-12")
    for i in container:
        text=i.find("li",class_="rgWa7D")
        if text:
            pixcel.append(text)
        else:
            pixcel.append(np.nan)

# %%
OS=[]
for i in range(1,41):
    url=("https://www.flipkart.com/search?q=tv&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off%22&page={i}")
    container=soup.find_all("ul",class_="_1xgFaf")
    for i in container:
        text=i.find("li",class_="rgWa7D")
        if text:
            OS.append(text.text)
        else:
            OS.append(np.nan)

# %%
Discount=[]
for i in range(1,41):
    url=("https://www.flipkart.com/search?q=tv&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off%22&page={i}")
    container=soup.find_all("div",class_="_3tbKJL")
    for i in container:
        text=i.find("div",class_="_3Ay6Sb")
        if text:
            Discount.append(text.text)
        else:
            Discount.append(np.nan)

# %%
LaunchingYear=[]
for i in range(1,41):
    url=("https://www.flipkart.com/search?q=tv&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off%22&page={i}")
    container=soup.find_all("li",class_="fMghEO")
    for i in container:
        text=i.find("li",class_="rgWa7D")
        if text:
            LaunchingYear.append(text.text)
        else:
            LaunchingYear.append(np.nan)

# %%
ActualPrice=[]
for i in range(1,41):
    url=("https://www.flipkart.com/search?q=tv&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off%22&page={i}")
    container=soup.find_all("div",class_="_3I9_wc _27UcVY")
    for i in container:
        text=i.text
        if text:
            ActualPrice.append(text)
        else:
            ActualPrice.append(np.nan)

# %%
EMI=[]
for i in range(1,41):
    url=("https://www.flipkart.com/search?q=tv&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off%22&page={i}")
    container=soup.find_all("div",class_="col col-5-12 nlI3QM")
    for i in container:
        text=i.find("div",class_="_3xFhiH")
        if text:
            EMI.append(text.text)
        else:
            EMI.append(np.nan)

# %% [markdown]
# OS=[]
# for i in range(1,11):
#     url="https://www.flipkart.com/search?q=tv&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"
#     container=soup.find_all("div",class_="fMghEO")
#     for i in container:
#         text=i.find("div",class_="rgWa7D")
#         if text:
#             OS.append(text)
#         else:
#             OS.append(np.nan)

# %% [markdown]
# Title=[]
# ActualPrice=[]
# SellingPrice=[]
# Rating=[]
# Warranty=[]
# Discount=[]
# OS=[]
# EMI=[]
# for i in range(1,46):
#     page=requests.get(r"https://www.flipkart.com/search?q=tv&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off")
#     soup=BeautifulSoup(page.text)
#     container=soup.find_all("div",class_="_2kHMtA")
#     for i in container:
#         text= i.find("div",class_="_4rR01T")
#         if text:
#             Title.append(text.text)
#         else:
#             Title.append(np.nan)

# %%
len(Title)
# Out:
# 960

# %%
len(ActualPrice)
# Out:
# 960

# %%
len(SellingPrice)
# Out:
# 960

# %%
len(Rating)
# Out:
# 960

# %%
len(Discount)
# Out:
# 960

# %%
LaunchingYear
# Out:
# []

# %%
len(Warranty)
# Out:
# 960

# %%
len(OS)
# Out:
# 960

# %%
len(EMI)
# Out:
# 960

# %%
TV={"Brand":Title,"ActualPrice":ActualPrice,"SellingPrice":SellingPrice,"Rating":Rating,"Warranty":Warranty,"Discount":Discount,"OS":OS,"EMI":EMI}

# %%
TVDF=pd.DataFrame(TV)

# %%
TVDF
# Out:
#                                                  Brand ActualPrice  \
# 0    BeethoSOL 80 cm (32 inch) HD Ready LED Smart A...     ₹19,000
# 1    Hisense E7K 139 cm (55 inch) QLED Ultra HD (4K...     ₹69,999
# 2    Mi A series 80 cm (32 inch) HD Ready LED Smart...     ₹24,999
# 3     MarQ by Flipkart 80 cm (32 inch) HD Ready LED TV     ₹17,000
# 4    Hisense E7K 108 cm (43 inch) QLED Ultra HD (4K...     ₹46,999
# ..                                                 ...         ...
# 955  LG 80 cm (32 inch) HD Ready LED Smart WebOS TV...     ₹19,990
# 956  MOTOROLA EnvisionX 102 cm (40 inch) Full HD LE...     ₹28,999
# 957  SAMSUNG Crystal 4K iSmart Series 138 cm (55 in...     ₹64,900
# 958          BeethoSOL 60 cm (24 inch) HD Ready LED TV     ₹15,000
# 959  Mi A series 100 cm (40 inch) Full HD LED Smart...     ₹29,999
#
#     SellingPrice     Rating  \
# 0         ₹7,899  [4.1, []]
# 1        ₹45,999  [4.2, []]
# 2        ₹12,999  [4.4, []]
# 3         ₹7,499  [4.2, []]
# ...

# %% [markdown]
# # Data Cleaning

# %%
TVDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 960 entries, 0 to 959
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         960 non-null    object
#  1   ActualPrice   960 non-null    object
#  2   SellingPrice  960 non-null    object
#  3   Rating        960 non-null    object
#  4   Warranty      960 non-null    object
#  5   Discount      960 non-null    object
#  6   OS            960 non-null    object
#  7   EMI           960 non-null    object
# dtypes: object(8)
# memory usage: 60.1+ KB

# %%
TVDF["Brand"][5]
# Out:
# 'Blaupunkt CyberSound G2 139 cm (55 inch) Ultra HD (4K) LED Smart Google TV 2023 Edition with Dolby Vis...'

# %%
TVDF["Brand"][0]
# Out:
# 'BeethoSOL 80 cm (32 inch) HD Ready LED Smart Android Based TV'

# %%
TVDF["Brand"][0].split()
# Out:
# ['BeethoSOL',
#  '80',
#  'cm',
#  '(32',
#  'inch)',
#  'HD',
#  'Ready',
#  'LED',
#  'Smart',
#  'Android',
#  'Based',
#  'TV']

# %%
TVDF
# Out:
#                                                  Brand ActualPrice  \
# 0    BeethoSOL 80 cm (32 inch) HD Ready LED Smart A...     ₹19,000
# 1    Hisense E7K 139 cm (55 inch) QLED Ultra HD (4K...     ₹69,999
# 2    Mi A series 80 cm (32 inch) HD Ready LED Smart...     ₹24,999
# 3     MarQ by Flipkart 80 cm (32 inch) HD Ready LED TV     ₹17,000
# 4    Hisense E7K 108 cm (43 inch) QLED Ultra HD (4K...     ₹46,999
# ..                                                 ...         ...
# 955  LG 80 cm (32 inch) HD Ready LED Smart WebOS TV...     ₹19,990
# 956  MOTOROLA EnvisionX 102 cm (40 inch) Full HD LE...     ₹28,999
# 957  SAMSUNG Crystal 4K iSmart Series 138 cm (55 in...     ₹64,900
# 958          BeethoSOL 60 cm (24 inch) HD Ready LED TV     ₹15,000
# 959  Mi A series 100 cm (40 inch) Full HD LED Smart...     ₹29,999
#
#     SellingPrice     Rating  \
# 0         ₹7,899  [4.1, []]
# 1        ₹45,999  [4.2, []]
# 2        ₹12,999  [4.4, []]
# 3         ₹7,499  [4.2, []]
# ...

# %%
Title=[]
for i in range(1,41):
    url=("https://www.flipkart.com/search?q=tv&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off%22&page={i}")
    soup=BeautifulSoup(page.text)
    container=soup.find_all("div",class_="_2kHMtA")
    for i in container:
        text=i.find("div",class_="_4rR01T").text
        name=text.split()[0]
        if name:
            Title.append(name)
        else:
            Title.append(np.nan)

# %%
len(Title)
# Out:
# 960

# %%
Rating=[]
for i in range(1,41):
    url=("https://www.flipkart.com/search?q=tv&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off%22&page={i}")
    soup=BeautifulSoup(page.text)
    container=soup.find_all("div",class_="col col-7-12")
    for i in container:
        text=i.find("div",class_="_3LWZlK").text
        name=text.split(",")[0]
        if name:
            Rating.append(name)
        else:
            Rating.append(np.nan)

# %%
len(Rating)
# Out:
# 960

# %% [markdown]
# Warranty=[]
# for i in range(1,11):
#     url="https://www.flipkart.com/search?q=tv&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"
#     soup=BeautifulSoup(page.text)
#     container=soup.find_all("ul",class_="_1xgFaf")
#     for i in container:
#         text=i.text
#         name=text.split()[9]
#         if name:
#             Warranty.append(name)
#         else:
#             Warranty.append(np.nan)

# %%
len(Warranty)
# Out:
# 960

# %%
Discount=[]
for i in range(1,41):
    url=("https://www.flipkart.com/search?q=tv&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off%22&page={i}")
    soup=BeautifulSoup(page.text)
    container=soup.find_all("div",class_="_3tbKJL")
    for i in container:
        text=i.find("div",class_="_3Ay6Sb").text
        name=text.split()[0]
        if text:
            Discount.append(name)
        else:
            Discount.append(np.nan)

# %%
(Discount)
# Out:
# ['58%',
#  '34%',
#  '48%',
#  '55%',
#  '34%',
#  '36%',
#  '57%',
#  '61%',
#  '44%',
#  '52%',
#  '48%',
#  '43%',
#  '57%',
#  '69%',
#  '28%',
#  '41%',
#  '52%',
#  '57%',
#  '34%',
#  '25%',
#  '37%',
#  '29%',
#  '60%',
#  '26%',
#  '58%',
#  '34%',
#  '48%',
#  '55%',
#  '34%',
#  '36%',
#  '57%',
#  '61%',
#  '44%',
#  '52%',
#  '48%',
#  '43%',
#  '57%',
#  '69%',
#  '28%',
#  '41%',
#  '52%',
#  '57%',
#  '34%',
#  '25%',
#  '37%',
#  '29%',
#  '60%',
#  '26%',
#  '58%',
#  '34%',
#  '48%',
#  '55%',
#  '34%',
#  '36%',
#  '57%',
#  '61%',
#  '44%',
#  '52%',
#  '48%',
#  '43%',
#  '57%',
#  '69%',
#  '28%',
#  '41%',
#  '52%',
#  '57%',
#  '34%',
#  '25%',
#  '37%',
#  '29%',
#  '60%',
#  '26%',
#  '58%',
#  '34%',
#  '48%',
#  '55%',
#  '34%',
#  '36%',
#  '57%',
#  '61%',
#  '44%',
#  '52%',
#  '48%',
#  '43%',
#  '57%',
#  '69%',
#  '28%',
#  '41%',
#  '52%',
#  '57%',
#  '34%',
#  '25%',
#  '37%',
#  '29%',
#  '60%',
#  '26%',
#  '58%',
#  '34%',
#  '48%',
#  '55%',
# ...

# %%
TVDF
# Out:
#                                                  Brand ActualPrice  \
# 0    BeethoSOL 80 cm (32 inch) HD Ready LED Smart A...     ₹19,000
# 1    Hisense E7K 139 cm (55 inch) QLED Ultra HD (4K...     ₹69,999
# 2    Mi A series 80 cm (32 inch) HD Ready LED Smart...     ₹24,999
# 3     MarQ by Flipkart 80 cm (32 inch) HD Ready LED TV     ₹17,000
# 4    Hisense E7K 108 cm (43 inch) QLED Ultra HD (4K...     ₹46,999
# ..                                                 ...         ...
# 955  LG 80 cm (32 inch) HD Ready LED Smart WebOS TV...     ₹19,990
# 956  MOTOROLA EnvisionX 102 cm (40 inch) Full HD LE...     ₹28,999
# 957  SAMSUNG Crystal 4K iSmart Series 138 cm (55 in...     ₹64,900
# 958          BeethoSOL 60 cm (24 inch) HD Ready LED TV     ₹15,000
# 959  Mi A series 100 cm (40 inch) Full HD LED Smart...     ₹29,999
#
#     SellingPrice     Rating  \
# 0         ₹7,899  [4.1, []]
# 1        ₹45,999  [4.2, []]
# 2        ₹12,999  [4.4, []]
# 3         ₹7,499  [4.2, []]
# ...

# %%
TVDF["Discount"]=TVDF["Discount"].str.replace("off","")

# %%
TVDF
# Out:
#                                                  Brand ActualPrice  \
# 0    BeethoSOL 80 cm (32 inch) HD Ready LED Smart A...     ₹19,000
# 1    Hisense E7K 139 cm (55 inch) QLED Ultra HD (4K...     ₹69,999
# 2    Mi A series 80 cm (32 inch) HD Ready LED Smart...     ₹24,999
# 3     MarQ by Flipkart 80 cm (32 inch) HD Ready LED TV     ₹17,000
# 4    Hisense E7K 108 cm (43 inch) QLED Ultra HD (4K...     ₹46,999
# ..                                                 ...         ...
# 955  LG 80 cm (32 inch) HD Ready LED Smart WebOS TV...     ₹19,990
# 956  MOTOROLA EnvisionX 102 cm (40 inch) Full HD LE...     ₹28,999
# 957  SAMSUNG Crystal 4K iSmart Series 138 cm (55 in...     ₹64,900
# 958          BeethoSOL 60 cm (24 inch) HD Ready LED TV     ₹15,000
# 959  Mi A series 100 cm (40 inch) Full HD LED Smart...     ₹29,999
#
#     SellingPrice     Rating  \
# 0         ₹7,899  [4.1, []]
# 1        ₹45,999  [4.2, []]
# 2        ₹12,999  [4.4, []]
# 3         ₹7,499  [4.2, []]
# ...

# %%
 TVDF["ActualPrice"]=[ActualPrice[1:].replace(",","")for ActualPrice in ActualPrice]

# %%
TVDF["ActualPrice"]
# Out:
# 0      19000
# 1      69999
# 2      24999
# 3      17000
# 4      46999
#        ...
# 955    19990
# 956    28999
# 957    64900
# 958    15000
# 959    29999
# Name: ActualPrice, Length: 960, dtype: object

# %%
TVDF
# Out:
#                                                  Brand ActualPrice  \
# 0    BeethoSOL 80 cm (32 inch) HD Ready LED Smart A...       19000
# 1    Hisense E7K 139 cm (55 inch) QLED Ultra HD (4K...       69999
# 2    Mi A series 80 cm (32 inch) HD Ready LED Smart...       24999
# 3     MarQ by Flipkart 80 cm (32 inch) HD Ready LED TV       17000
# 4    Hisense E7K 108 cm (43 inch) QLED Ultra HD (4K...       46999
# ..                                                 ...         ...
# 955  LG 80 cm (32 inch) HD Ready LED Smart WebOS TV...       19990
# 956  MOTOROLA EnvisionX 102 cm (40 inch) Full HD LE...       28999
# 957  SAMSUNG Crystal 4K iSmart Series 138 cm (55 in...       64900
# 958          BeethoSOL 60 cm (24 inch) HD Ready LED TV       15000
# 959  Mi A series 100 cm (40 inch) Full HD LED Smart...       29999
#
#     SellingPrice     Rating  \
# 0         ₹7,899  [4.1, []]
# 1        ₹45,999  [4.2, []]
# 2        ₹12,999  [4.4, []]
# 3         ₹7,499  [4.2, []]
# ...

# %%
 TVDF["SellingPrice"]=[SellingPrice[1:].replace(",","")for SellingPrice in SellingPrice]

# %%
TVDF
# Out:
#                                                  Brand ActualPrice  \
# 0    BeethoSOL 80 cm (32 inch) HD Ready LED Smart A...       19000
# 1    Hisense E7K 139 cm (55 inch) QLED Ultra HD (4K...       69999
# 2    Mi A series 80 cm (32 inch) HD Ready LED Smart...       24999
# 3     MarQ by Flipkart 80 cm (32 inch) HD Ready LED TV       17000
# 4    Hisense E7K 108 cm (43 inch) QLED Ultra HD (4K...       46999
# ..                                                 ...         ...
# 955  LG 80 cm (32 inch) HD Ready LED Smart WebOS TV...       19990
# 956  MOTOROLA EnvisionX 102 cm (40 inch) Full HD LE...       28999
# 957  SAMSUNG Crystal 4K iSmart Series 138 cm (55 in...       64900
# 958          BeethoSOL 60 cm (24 inch) HD Ready LED TV       15000
# 959  Mi A series 100 cm (40 inch) Full HD LED Smart...       29999
#
#     SellingPrice     Rating  \
# 0           7899  [4.1, []]
# 1          45999  [4.2, []]
# 2          12999  [4.4, []]
# 3           7499  [4.2, []]
# ...

# %% [markdown]
# TVDF["Rating"]=TVDF["Rating"].str.strip("]")

# %% [markdown]
# TVDF["Rating"]

# %%
Rating=[]
for i in range(1,41):
    url="https://www.flipkart.com/search?q=tv&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"
    soup=BeautifulSoup(page.text)
    container=soup.find_all("div",class_="col col-7-12")
    for i in container:
        text=i.find("div",class_="_3LWZlK").text
        name=text.split()[0]
        if text:
            Rating.append(name)
        else:
            Rating.append(np.nan)

# %%
Rating
# Out:
# ['4.1',
#  '4.2',
#  '4.4',
#  '4.2',
#  '4.2',
#  '4.5',
#  '4.2',
#  '4.1',
#  '4.3',
#  '4.1',
#  '4.3',
#  '4.1',
#  '4.1',
#  '4.1',
#  '4.4',
#  '4.3',
#  '4.3',
#  '4.1',
#  '4.3',
#  '4.4',
#  '4.2',
#  '4.3',
#  '4.1',
#  '4.4',
#  '4.1',
#  '4.2',
#  '4.4',
#  '4.2',
#  '4.2',
#  '4.5',
#  '4.2',
#  '4.1',
#  '4.3',
#  '4.1',
#  '4.3',
#  '4.1',
#  '4.1',
#  '4.1',
#  '4.4',
#  '4.3',
#  '4.3',
#  '4.1',
#  '4.3',
#  '4.4',
#  '4.2',
#  '4.3',
#  '4.1',
#  '4.4',
#  '4.1',
#  '4.2',
#  '4.4',
#  '4.2',
#  '4.2',
#  '4.5',
#  '4.2',
#  '4.1',
#  '4.3',
#  '4.1',
#  '4.3',
#  '4.1',
#  '4.1',
#  '4.1',
#  '4.4',
#  '4.3',
#  '4.3',
#  '4.1',
#  '4.3',
#  '4.4',
#  '4.2',
#  '4.3',
#  '4.1',
#  '4.4',
#  '4.1',
#  '4.2',
#  '4.4',
#  '4.2',
#  '4.2',
#  '4.5',
#  '4.2',
#  '4.1',
#  '4.3',
#  '4.1',
#  '4.3',
#  '4.1',
#  '4.1',
#  '4.1',
#  '4.4',
#  '4.3',
#  '4.3',
#  '4.1',
#  '4.3',
#  '4.4',
#  '4.2',
#  '4.3',
#  '4.1',
#  '4.4',
#  '4.1',
#  '4.2',
#  '4.4',
#  '4.2',
# ...

# %%
TV={"Brand":Title,"ActualPrice":ActualPrice,"SellingPrice":SellingPrice,"Rating":Rating,"Warranty":Warranty,"Discount":Discount,"OS":OS,"EMI":EMI}

# %%
TVDF
# Out:
#                                                  Brand ActualPrice  \
# 0    BeethoSOL 80 cm (32 inch) HD Ready LED Smart A...       19000
# 1    Hisense E7K 139 cm (55 inch) QLED Ultra HD (4K...       69999
# 2    Mi A series 80 cm (32 inch) HD Ready LED Smart...       24999
# 3     MarQ by Flipkart 80 cm (32 inch) HD Ready LED TV       17000
# 4    Hisense E7K 108 cm (43 inch) QLED Ultra HD (4K...       46999
# ..                                                 ...         ...
# 955  LG 80 cm (32 inch) HD Ready LED Smart WebOS TV...       19990
# 956  MOTOROLA EnvisionX 102 cm (40 inch) Full HD LE...       28999
# 957  SAMSUNG Crystal 4K iSmart Series 138 cm (55 in...       64900
# 958          BeethoSOL 60 cm (24 inch) HD Ready LED TV       15000
# 959  Mi A series 100 cm (40 inch) Full HD LED Smart...       29999
#
#     SellingPrice     Rating  \
# 0           7899  [4.1, []]
# 1          45999  [4.2, []]
# 2          12999  [4.4, []]
# 3           7499  [4.2, []]
# ...

# %%
 TVDF["ActualPrice"]=[ActualPrice[1:].replace(",","")for ActualPrice in ActualPrice]

# %%
TVDF["ActualPrice"]
# Out:
# 0      19000
# 1      69999
# 2      24999
# 3      17000
# 4      46999
#        ...
# 955    19990
# 956    28999
# 957    64900
# 958    15000
# 959    29999
# Name: ActualPrice, Length: 960, dtype: object

# %%
TVDF
# Out:
#                                                  Brand ActualPrice  \
# 0    BeethoSOL 80 cm (32 inch) HD Ready LED Smart A...       19000
# 1    Hisense E7K 139 cm (55 inch) QLED Ultra HD (4K...       69999
# 2    Mi A series 80 cm (32 inch) HD Ready LED Smart...       24999
# 3     MarQ by Flipkart 80 cm (32 inch) HD Ready LED TV       17000
# 4    Hisense E7K 108 cm (43 inch) QLED Ultra HD (4K...       46999
# ..                                                 ...         ...
# 955  LG 80 cm (32 inch) HD Ready LED Smart WebOS TV...       19990
# 956  MOTOROLA EnvisionX 102 cm (40 inch) Full HD LE...       28999
# 957  SAMSUNG Crystal 4K iSmart Series 138 cm (55 in...       64900
# 958          BeethoSOL 60 cm (24 inch) HD Ready LED TV       15000
# 959  Mi A series 100 cm (40 inch) Full HD LED Smart...       29999
#
#     SellingPrice     Rating  \
# 0           7899  [4.1, []]
# 1          45999  [4.2, []]
# 2          12999  [4.4, []]
# 3           7499  [4.2, []]
# ...

# %%
Rating=[]
for i in range(1,41):
    url="https://www.flipkart.com/search?q=tv&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"
    soup=BeautifulSoup(page.text)
    container=soup.find_all("div",class_="col col-7-12")
    for i in container:
        text=i.find("div",class_="_3LWZlK").text
        name=text.split()[0]
        if text:
            Rating.append(name)
        else:
            Rating.append(np.nan)

# %%
Rating
# Out:
# ['4.1',
#  '4.2',
#  '4.4',
#  '4.2',
#  '4.2',
#  '4.5',
#  '4.2',
#  '4.1',
#  '4.3',
#  '4.1',
#  '4.3',
#  '4.1',
#  '4.1',
#  '4.1',
#  '4.4',
#  '4.3',
#  '4.3',
#  '4.1',
#  '4.3',
#  '4.4',
#  '4.2',
#  '4.3',
#  '4.1',
#  '4.4',
#  '4.1',
#  '4.2',
#  '4.4',
#  '4.2',
#  '4.2',
#  '4.5',
#  '4.2',
#  '4.1',
#  '4.3',
#  '4.1',
#  '4.3',
#  '4.1',
#  '4.1',
#  '4.1',
#  '4.4',
#  '4.3',
#  '4.3',
#  '4.1',
#  '4.3',
#  '4.4',
#  '4.2',
#  '4.3',
#  '4.1',
#  '4.4',
#  '4.1',
#  '4.2',
#  '4.4',
#  '4.2',
#  '4.2',
#  '4.5',
#  '4.2',
#  '4.1',
#  '4.3',
#  '4.1',
#  '4.3',
#  '4.1',
#  '4.1',
#  '4.1',
#  '4.4',
#  '4.3',
#  '4.3',
#  '4.1',
#  '4.3',
#  '4.4',
#  '4.2',
#  '4.3',
#  '4.1',
#  '4.4',
#  '4.1',
#  '4.2',
#  '4.4',
#  '4.2',
#  '4.2',
#  '4.5',
#  '4.2',
#  '4.1',
#  '4.3',
#  '4.1',
#  '4.3',
#  '4.1',
#  '4.1',
#  '4.1',
#  '4.4',
#  '4.3',
#  '4.3',
#  '4.1',
#  '4.3',
#  '4.4',
#  '4.2',
#  '4.3',
#  '4.1',
#  '4.4',
#  '4.1',
#  '4.2',
#  '4.4',
#  '4.2',
# ...

# %%
TV={"Brand":Title,"ActualPrice":ActualPrice,"SellingPrice":SellingPrice,"Rating":Rating,"Warranty":Warranty,"Discount":Discount,"OS":OS,"Offers":EMI}

# %%
TVDF=pd.DataFrame(TV)

# %%
TVDF
# Out:
#          Brand ActualPrice SellingPrice Rating  \
# 0    BeethoSOL     ₹19,000       ₹7,899    4.1
# 1      Hisense     ₹69,999      ₹45,999    4.2
# 2           Mi     ₹24,999      ₹12,999    4.4
# 3         MarQ     ₹17,000       ₹7,499    4.2
# 4      Hisense     ₹46,999      ₹30,999    4.2
# ..         ...         ...          ...    ...
# 955         LG     ₹19,990      ₹14,990    4.4
# 956   MOTOROLA     ₹28,999      ₹17,999    4.2
# 957    SAMSUNG     ₹64,900      ₹45,990    4.3
# 958  BeethoSOL     ₹15,000       ₹5,899    4.1
# 959         Mi     ₹29,999      ₹21,999    4.4
#
#                                               Warranty Discount  \
# 0    Operating System: Android BasedHD Ready 1366 x...      58%
# 1    Operating System: VIDAAUltra HD (4K) 3840 × 21...      34%
# 2    Operating System: Google TVHD Ready 1366 x 768...      48%
# 3    HD Ready 1366 x 768 PixelsLaunch Year: 20231 Y...      55%
# 4    Operating System: VIDAAUltra HD (4K) 3840 × 21...      34%
# ...

# %%
 TVDF["SellingPrice"]=[SellingPrice[1:].replace(",","")for SellingPrice in SellingPrice]

# %%
TVDF
# Out:
#          Brand ActualPrice SellingPrice Rating  \
# 0    BeethoSOL     ₹19,000         7899    4.1
# 1      Hisense     ₹69,999        45999    4.2
# 2           Mi     ₹24,999        12999    4.4
# 3         MarQ     ₹17,000         7499    4.2
# 4      Hisense     ₹46,999        30999    4.2
# ..         ...         ...          ...    ...
# 955         LG     ₹19,990        14990    4.4
# 956   MOTOROLA     ₹28,999        17999    4.2
# 957    SAMSUNG     ₹64,900        45990    4.3
# 958  BeethoSOL     ₹15,000         5899    4.1
# 959         Mi     ₹29,999        21999    4.4
#
#                                               Warranty Discount  \
# 0    Operating System: Android BasedHD Ready 1366 x...      58%
# 1    Operating System: VIDAAUltra HD (4K) 3840 × 21...      34%
# 2    Operating System: Google TVHD Ready 1366 x 768...      48%
# 3    HD Ready 1366 x 768 PixelsLaunch Year: 20231 Y...      55%
# 4    Operating System: VIDAAUltra HD (4K) 3840 × 21...      34%
# ...

# %%
 TVDF["ActualPrice"]=[ActualPrice[1:].replace(",","")for ActualPrice in ActualPrice]

# %%
TVDF["ActualPrice"]
# Out:
# 0      19000
# 1      69999
# 2      24999
# 3      17000
# 4      46999
#        ...
# 955    19990
# 956    28999
# 957    64900
# 958    15000
# 959    29999
# Name: ActualPrice, Length: 960, dtype: object

# %%
TVDF
# Out:
#          Brand ActualPrice SellingPrice Rating  \
# 0    BeethoSOL       19000         7899    4.1
# 1      Hisense       69999        45999    4.2
# 2           Mi       24999        12999    4.4
# 3         MarQ       17000         7499    4.2
# 4      Hisense       46999        30999    4.2
# ..         ...         ...          ...    ...
# 955         LG       19990        14990    4.4
# 956   MOTOROLA       28999        17999    4.2
# 957    SAMSUNG       64900        45990    4.3
# 958  BeethoSOL       15000         5899    4.1
# 959         Mi       29999        21999    4.4
#
#                                               Warranty Discount  \
# 0    Operating System: Android BasedHD Ready 1366 x...      58%
# 1    Operating System: VIDAAUltra HD (4K) 3840 × 21...      34%
# 2    Operating System: Google TVHD Ready 1366 x 768...      48%
# 3    HD Ready 1366 x 768 PixelsLaunch Year: 20231 Y...      55%
# 4    Operating System: VIDAAUltra HD (4K) 3840 × 21...      34%
# ...

# %%
TVDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 960 entries, 0 to 959
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         960 non-null    object
#  1   ActualPrice   960 non-null    object
#  2   SellingPrice  960 non-null    object
#  3   Rating        960 non-null    object
#  4   Warranty      960 non-null    object
#  5   Discount      960 non-null    object
#  6   OS            960 non-null    object
#  7   Offers        960 non-null    object
# dtypes: object(8)
# memory usage: 60.1+ KB

# %%
 TVDF["OS"]=[OS[1:].split(":")[-1]for OS in OS]

# %%
TVDF
# Out:
#          Brand ActualPrice SellingPrice Rating  \
# 0    BeethoSOL       19000         7899    4.1
# 1      Hisense       69999        45999    4.2
# 2           Mi       24999        12999    4.4
# 3         MarQ       17000         7499    4.2
# 4      Hisense       46999        30999    4.2
# ..         ...         ...          ...    ...
# 955         LG       19990        14990    4.4
# 956   MOTOROLA       28999        17999    4.2
# 957    SAMSUNG       64900        45990    4.3
# 958  BeethoSOL       15000         5899    4.1
# 959         Mi       29999        21999    4.4
#
#                                               Warranty Discount  \
# 0    Operating System: Android BasedHD Ready 1366 x...      58%
# 1    Operating System: VIDAAUltra HD (4K) 3840 × 21...      34%
# 2    Operating System: Google TVHD Ready 1366 x 768...      48%
# 3    HD Ready 1366 x 768 PixelsLaunch Year: 20231 Y...      55%
# 4    Operating System: VIDAAUltra HD (4K) 3840 × 21...      34%
# ...

# %%
 TVDF["Warranty"]=[Warranty[1:].split(":")[-1][5:6]for Warranty in Warranty]

# %%
TVDF["Warranty"]
# Out:
# 0      1
# 1      2
# 2      1
# 3      1
# 4      2
#       ..
# 955    a
# 956    1
# 957    1
# 958    1
# 959    1
# Name: Warranty, Length: 960, dtype: object

# %%
TVDF["Discount"]=

# %%
TVDF
# Out:
#          Brand ActualPrice SellingPrice Rating Warranty Discount  \
# 0    BeethoSOL       19000         7899    4.1        1       58
# 1      Hisense       69999        45999    4.2        2       34
# 2           Mi       24999        12999    4.4        1       48
# 3         MarQ       17000         7499    4.2        1       55
# 4      Hisense       46999        30999    4.2        2       34
# ..         ...         ...          ...    ...      ...      ...
# 955         LG       19990        14990    4.4        a       25
# 956   MOTOROLA       28999        17999    4.2        1       37
# 957    SAMSUNG       64900        45990    4.3        1       29
# 958  BeethoSOL       15000         5899    4.1        1       60
# 959         Mi       29999        21999    4.4        1       26
#
#                             OS                       Offers
# 0                Android Based                   Bank Offer
# 1                        VIDAA  Upto ₹2,000 Off on Exchange
# ...

# %%
TVDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 960 entries, 0 to 959
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         960 non-null    object
#  1   ActualPrice   960 non-null    object
#  2   SellingPrice  960 non-null    object
#  3   Rating        960 non-null    object
#  4   Warranty      960 non-null    object
#  5   Discount      960 non-null    object
#  6   OS            960 non-null    object
#  7   Offers        960 non-null    object
# dtypes: object(8)
# memory usage: 60.1+ KB

# %%
TVDF.replace({"Warranty":["a"]},1,inplace=True)

# %%
TVDF
# Out:
#          Brand ActualPrice SellingPrice Rating Warranty Discount  \
# 0    BeethoSOL       19000         7899    4.1        1       58
# 1      Hisense       69999        45999    4.2        2       34
# 2           Mi       24999        12999    4.4        1       48
# 3         MarQ       17000         7499    4.2        1       55
# 4      Hisense       46999        30999    4.2        2       34
# ..         ...         ...          ...    ...      ...      ...
# 955         LG       19990        14990    4.4        1       25
# 956   MOTOROLA       28999        17999    4.2        1       37
# 957    SAMSUNG       64900        45990    4.3        1       29
# 958  BeethoSOL       15000         5899    4.1        1       60
# 959         Mi       29999        21999    4.4        1       26
#
#                             OS                       Offers
# 0                Android Based                   Bank Offer
# 1                        VIDAA  Upto ₹2,000 Off on Exchange
# ...

# %%
TVDF=TVDF.astype({"ActualPrice":np.int64,"SellingPrice":np.int64,"Rating":float,"Warranty":np.int16,"Discount":np.int64})

# %%
TVDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 960 entries, 0 to 959
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         960 non-null    object
#  1   ActualPrice   960 non-null    int64
#  2   SellingPrice  960 non-null    int64
#  3   Rating        960 non-null    float64
#  4   Warranty      960 non-null    int16
#  5   Discount      960 non-null    int64
#  6   OS            960 non-null    object
#  7   Offers        960 non-null    object
# dtypes: float64(1), int16(1), int64(3), object(3)
# memory usage: 54.5+ KB

# %% [markdown]
# # Analysis

# %%
TVDF
# Out:
#          Brand  ActualPrice  SellingPrice  Rating  Warranty  Discount  \
# 0           Mi        24999         12999     4.4         1        48
# 1    BeethoSOL        19000          7899     4.1         1        58
# 2     iFFALCON        19990          9499     4.2         1        52
# 3     iFFALCON        73990         29999     4.2         1        59
# 4      SAMSUNG        18900         14490     4.3         1        23
# ..         ...          ...           ...     ...       ...       ...
# 955        TCL        20990         10990     4.1         2        47
# 956  BeethoSOL        15000          5799     4.1         1        61
# 957  BeethoSOL        19000          8099     4.1         1        57
# 958    TOSHIBA        79990         48999     4.3         2        38
# 959         Mi        42999         25999     4.3         1        39
#
#                             OS                        Offers
# 0                    Google TV   Upto ₹2,000 Off on Exchange
# ...

# %%
TVDF.to_csv("Telivision_Project.csv")

# %%
import csv

with open("Telivision_Project.csv","r") as f:
    obj_r=csv.reader(f)
    for x in obj_r:
        print(x)
# Out:
# ['', 'Brand', 'ActualPrice', 'SellingPrice', 'Rating', 'Warranty', 'Discount', 'OS', 'Offers']
# ['0', 'BeethoSOL', '19000', '7899', '4.1', '1', '58', ' Android Based', 'Bank Offer']
# ['1', 'Hisense', '69999', '45999', '4.2', '2', '34', ' VIDAA', 'Upto â‚¹2,000 Off on Exchange']
# ['2', 'Mi', '24999', '12999', '4.4', '1', '48', ' Google TV', 'Upto â‚¹2,000 Off on Exchange']
# ['3', 'MarQ', '17000', '7499', '4.2', '1', '55', 'D Ready 1366 x 768 Pixels', 'Bank Offer']
# ['4', 'Hisense', '46999', '30999', '4.2', '2', '34', ' VIDAA', 'Upto â‚¹2,000 Off on Exchange']
# ['5', 'Blaupunkt', '46999', '29999', '4.5', '1', '36', ' Google TV', 'Upto â‚¹2,000 Off on Exchange']
# ['6', 'BeethoSOL', '17000', '7299', '4.2', '1', '57', 'D Ready 1366 x 768 Pixels', 'Bank Offer']
# ['7', 'BeethoSOL', '15000', '5799', '4.1', '1', '61', 'D Ready 1366 x 768 Pixels', 'Bank Offer']
# ['8', 'Acer', '49999', '27999', '4.3', '1', '44', ' Google TV', 'Upto â‚¹2,000 Off on Exchange']
# ...

# %%
TVDF["Brand"].unique()
# Out:
# array(['BeethoSOL', 'Hisense', 'Mi', 'MarQ', 'Blaupunkt', 'Acer', 'TCL',
#        'Thomson', 'OnePlus', 'SAMSUNG', 'NU', 'LG', 'MOTOROLA'],
#       dtype=object)

# %%
len(TVDF["Brand"].unique())
# Out:
# 13

# %%
TVDF.loc[TVDF["ActualPrice"]>=50000,["Brand","Discount","SellingPrice","ActualPrice"]]
# Out:
#        Brand  Discount  SellingPrice  ActualPrice
# 1    Hisense        34         45999        69999
# 9        TCL        52         24990        52990
# 10      Acer        48         30999        59999
# 14   OnePlus        28         42653        59999
# 15   SAMSUNG        41         30990        52900
# ..       ...       ...           ...          ...
# 945      TCL        52         24990        52990
# 946     Acer        48         30999        59999
# 950  OnePlus        28         42653        59999
# 951  SAMSUNG        41         30990        52900
# 957  SAMSUNG        29         45990        64900
#
# [240 rows x 4 columns]

# %%
TVDF.loc[TVDF["ActualPrice"]<=50000,["Brand","Discount","SellingPrice","ActualPrice"]]
# Out:
#          Brand  Discount  SellingPrice  ActualPrice
# 0    BeethoSOL        58          7899        19000
# 2           Mi        48         12999        24999
# 3         MarQ        55          7499        17000
# 4      Hisense        34         30999        46999
# 5    Blaupunkt        36         29999        46999
# ..         ...       ...           ...          ...
# 954         Mi        34         32999        49999
# 955         LG        25         14990        19990
# 956   MOTOROLA        37         17999        28999
# 958  BeethoSOL        60          5899        15000
# 959         Mi        26         21999        29999
#
# [720 rows x 4 columns]

# %%
TVDF.loc[TVDF["Discount"]<=50,["Brand","Discount"]]
# Out:
#          Brand  Discount
# 1      Hisense        34
# 2           Mi        48
# 4      Hisense        34
# 5    Blaupunkt        36
# 8         Acer        44
# ..         ...       ...
# 954         Mi        34
# 955         LG        25
# 956   MOTOROLA        37
# 957    SAMSUNG        29
# 959         Mi        26
#
# [560 rows x 2 columns]

# %%
TVDF.loc[TVDF["Discount"]>=50,["Brand","Warranty","Discount"]]
# Out:
#          Brand  Warranty  Discount
# 0    BeethoSOL         1        58
# 3         MarQ         1        55
# 6    BeethoSOL         1        57
# 7    BeethoSOL         1        61
# 9          TCL         2        52
# ..         ...       ...       ...
# 948  BeethoSOL         1        57
# 949  BeethoSOL         1        69
# 952         NU         2        52
# 953  BeethoSOL         1        57
# 958  BeethoSOL         1        60
#
# [400 rows x 3 columns]

# %%
TVDF.loc[TVDF["Discount"]<=50,["Brand","Warranty","Discount"]]
# Out:
#          Brand  Warranty  Discount
# 1      Hisense         2        34
# 2           Mi         1        48
# 4      Hisense         2        34
# 5    Blaupunkt         1        36
# 8         Acer         1        44
# ..         ...       ...       ...
# 954         Mi         1        34
# 955         LG         1        25
# 956   MOTOROLA         1        37
# 957    SAMSUNG         1        29
# 959         Mi         1        26
#
# [560 rows x 3 columns]

# %%
TVDF.loc[TVDF["Rating"]>=4.3,["Brand","Rating","OS"]]
# Out:
#          Brand  Rating          OS
# 2           Mi     4.4   Google TV
# 5    Blaupunkt     4.5   Google TV
# 8         Acer     4.3   Google TV
# 10        Acer     4.3   Google TV
# 14     OnePlus     4.4     Android
# ..         ...     ...         ...
# 952         NU     4.3       WebOS
# 954         Mi     4.3   Google TV
# 955         LG     4.4       WebOS
# 957    SAMSUNG     4.3       Tizen
# 959         Mi     4.4   Google TV
#
# [440 rows x 3 columns]

# %% [markdown]
# # Visualization

# %%
TVDF
# Out:
#          Brand  ActualPrice  SellingPrice  Rating  Warranty  Discount  \
# 0    BeethoSOL        19000          7899     4.1         1        58
# 1      Hisense        69999         45999     4.2         2        34
# 2           Mi        24999         12999     4.4         1        48
# 3         MarQ        17000          7499     4.2         1        55
# 4      Hisense        46999         30999     4.2         2        34
# ..         ...          ...           ...     ...       ...       ...
# 955         LG        19990         14990     4.4         1        25
# 956   MOTOROLA        28999         17999     4.2         1        37
# 957    SAMSUNG        64900         45990     4.3         1        29
# 958  BeethoSOL        15000          5899     4.1         1        60
# 959         Mi        29999         21999     4.4         1        26
#
#                             OS                       Offers
# 0                Android Based                   Bank Offer
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(TVDF["Rating"])
plt.show()

# %%
plt.boxplot(TVDF["SellingPrice"])
plt.show()

# %%
import seaborn as sns

# %%
sns.countplot(x="Brand",data=TVDF,hue="Brand",palette="gist_rainbow")
plt.show()

# %%
TVDF["OS"].value_counts().plot(kind="pie",autopct="%0.2F%%")
plt.show()
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.distplot(TVDF["Discount"],label="Rating",bins=10,color="g")
plt.legend()
plt.show()
# Out:
# C:\Users\GOPI\AppData\Local\Temp\ipykernel_4636\3724441577.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(TVDF["Discount"],label="Rating",bins=10,color="g")

# %%
sns.distplot(TVDF["ActualPrice"],label="ActualPrice",bins=10,color="b",hist=False)
plt.legend()
plt.show()
# Out:
# C:\Users\GOPI\AppData\Local\Temp\ipykernel_4636\3682871554.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(TVDF["ActualPrice"],label="ActualPrice",bins=10,color="b",hist=False)

# %%
sns.distplot(TVDF["Rating"],label="Rating",bins=15,color="g",kde=False)
plt.legend()
plt.show()
# Out:
# C:\Users\GOPI\AppData\Local\Temp\ipykernel_4636\1277374874.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(TVDF["Rating"],label="Rating",bins=15,color="g",kde=False)

# %%
TVDF["Rating"].plot(kind="hist",color="r",label="Rating")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.distplot(TVDF["SellingPrice"], bins = 25, rug=True)
# Out:
# C:\Users\GOPI\AppData\Local\Temp\ipykernel_4636\2941599054.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(TVDF["SellingPrice"], bins = 25, rug=True)
# <Axes: xlabel='SellingPrice', ylabel='Density'>

# %%
plt.figure(figsize=(10,6))
sns.distplot(TVDF["ActualPrice"], bins = 25, rug=True)
# Out:
# C:\Users\GOPI\AppData\Local\Temp\ipykernel_4636\1335797471.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(TVDF["ActualPrice"], bins = 25, rug=True)
# <Axes: xlabel='ActualPrice', ylabel='Density'>

# %%
sns.violinplot(y = "Rating", data = TVDF, width=0.5, color="yellow")
plt.show()

# %% [markdown]
# # Bi-variated

# %%
sns.barplot(x = TVDF["Brand"], y =TVDF["Discount"])
plt.show()

# %%
sns.violinplot(x="Brand",y = "ActualPrice", data = TVDF, width=0.5, color="red")
plt.show()

# %%
sns.violinplot(x="Brand",y = "SellingPrice", data = TVDF, width=0.5, color="red")
plt.show()

# %%
sns.scatterplot(x = "Brand", y = "SellingPrice", data = TVDF,hue="Brand")
# Out:
# <Axes: xlabel='Brand', ylabel='SellingPrice'>

# %%
plt.hist([TVDF["Discount"], TVDF["SellingPrice"]], bins=20, rwidth=2)
plt.show()

# %% [markdown]
# # Multivariatae

# %%
sns.heatmap(TVDF.corr(),annot=True)
plt.show()
# Out:
# C:\Users\GOPI\AppData\Local\Temp\ipykernel_4636\381823994.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(TVDF.corr(),annot=True)

# %%
sns.scatterplot(x = "Rating", y = "SellingPrice", data = TVDF,hue = "Brand", sizes =(30,60))
plt.show()

# %%
sns.barplot(x = TVDF["Brand"], y =TVDF["Rating"],hue=TVDF["OS"])
plt.show()

# %%
sns.pairplot(data=TVDF)
plt.show()
